# %%
import DNN_BackTester as DNN
# Out:
# 1
# /Users/zibolin/miniforge3/envs/ml/lib/python3.8/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
tester = DNN.DNN_Backtester(symbol = "EUR_USD",start="2019-01-01",end = "2022-01-01",granularity = "M15")

# %%
tester.test_strategy()
# Out:
# 2022-02-05 14:55:04.164987: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-02-05 14:55:14.855136: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 701/701 [==============================] - 3s 4ms/step - loss: 0.6926 - accuracy: 0.5148
# 2022-02-05 15:04:06.297649: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# (0.953276, 0.013172)

# %%
tester.hit_ratio()
# Out:
# 0.49118421639958937

# %%
tester.plot_results()

# %%
tester.results.trades.value_counts()
# Out:
# 0.00000    22127
# 2.00000      274
# 1.00000        1
# Name: trades, dtype: int64

# %%
tester.save_model()
# Out:
# 2022-02-05 15:13:41.577888: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: DNN_model/assets
